# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Alexandra Zipse**
# Data Analyst

# %% [markdown]
# *I am interested in data science because I enjoy working with information. I find the complexity of data to be fascinating. I love being able to find problems and find solutions to those problems. In order to do this, I must be able to search, collect, analyze, and utilize data. I hope to one day use my data analytical skills to create my own business, apps, and other solutions.*

# %% [markdown]
# ### The code here is supposed to multiply two numbers together

# %%
number = 100 * 5 
print (number)
# Out:
# 500

# %% [markdown]
# The image below shows 9 different dog breeds. `These dog breeds include:`
#
#    - Labrador Retreiver
#    - Berner Sennenhund
#    - Siberian Husky
#    - Jack Russell Terrier
#    - Pug
#    - Pomeranian
#    - Beagle
#    - German Shepherd
#    - Mastiff
#
#   ![different-type-of-dogs-set-isolated-big-and-small-vector-7521111.jpg](attachment:different-type-of-dogs-set-isolated-big-and-small-vector-7521111.jpg)
